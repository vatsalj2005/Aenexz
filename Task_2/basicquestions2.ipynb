# %% [markdown]
# # Basic Questions 2

# %% [markdown]
# ## 1. Function to Return Area of a Circle

# %%
import math

def circle_area(radius):
    return math.pi * radius ** 2

radius = float(input('Enter the radius: '))
print(f'Area of circle with radius {radius} = {circle_area(radius):.4f}')

# %% [markdown]
# ## 2. Function to Return the Largest of Three Numbers

# %%
def largest_of_three(a, b, c):
    if a >= b and a >= c:
        return a
    elif b >= a and b >= c:
        return b
    else:
        return c

a = float(input('Enter first number: '))
b = float(input('Enter second number: '))
c = float(input('Enter third number: '))

print(f'The largest number is: {largest_of_three(a, b, c)}')

# %% [markdown]
# ## 3. Function to Return String Length (without built-in len)

# %%
def string_length(s):
    count = 0
    for _ in s:
        count += 1
    return count

s = input('Enter a string: ')
print(f"Length of '{s}' = {string_length(s)}")

# %% [markdown]
# ## 4. Function to Check Whether a Number is Prime

# %%
def is_prime(n):
    if n < 2:
        return False
    for i in range(2, int(n ** 0.5) + 1):
        if n % i == 0:
            return False
    return True

num = int(input('Enter a number: '))
if is_prime(num):
    print(f'{num} is a prime number.')
else:
    print(f'{num} is not a prime number.')

# %% [markdown]
# ## 5. Recursive Function to Find the Nth Fibonacci Number

# %%
def fibonacci(n):
    if n <= 0:
        return 0
    elif n == 1:
        return 1
    else:
        return fibonacci(n - 1) + fibonacci(n - 2)

n = int(input('Enter n: '))
print(f'Fibonacci({n}) = {fibonacci(n)}')

# %% [markdown]
# ## 6. Recursive Function to Reverse a String

# %%
def reverse_string(s):
    if len(s) == 0:
        return s
    return reverse_string(s[1:]) + s[0]

s = input('Enter a string: ')
print(f'Reversed: {reverse_string(s)}')

# %% [markdown]
# ## 7. Sum of All Numbers from 1 to N (for loop)

# %%
n = int(input('Enter n: '))

total = 0
for i in range(1, n + 1):
    total += i

print(f'Sum of numbers from 1 to {n} = {total}')

# %% [markdown]
# ## 8. Count Even Numbers in a List

# %%
numbers = list(map(int, input('Enter numbers separated by spaces: ').split()))

count = 0
for num in numbers:
    if num % 2 == 0:
        count += 1

print(f'Count of even numbers: {count}')

# %% [markdown]
# ## 9. Print All Prime Numbers Between 1 and 100

# %%
def is_prime(n):
    if n < 2:
        return False
    for i in range(2, int(n ** 0.5) + 1):
        if n % i == 0:
            return False
    return True

primes = [n for n in range(1, 101) if is_prime(n)]
print('Prime numbers between 1 and 100:')
print(primes)
